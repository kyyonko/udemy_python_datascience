# %% [markdown]
# # 52. 回帰とプロット

# %%
import numpy as np
from numpy.random import randn
import pandas as pd

from scipy import stats

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Seabornにサンプルデータがある
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# lmplot() x = total_bill y = tips でプロットする
sns.lmplot("total_bill", "tip", tips)

# %%
# グラフ毎にパラメータを変えられる
sns.lmplot("total_bill", "tip", tips, 
          scatter_kws = {'marker': 'o', 'color': 'indianred'}, 
          line_kws = {'linewidth': 1, 'color': 'blue'})

# %%
# 4次関数で回帰曲線を引くこともできる
sns.lmplot("total_bill", "tip", tips, order = 4,
          scatter_kws = {'marker': 'o', 'color': 'indianred'}, 
          line_kws = {'linewidth': 1, 'color': 'blue'})

# %%
# 単なるプロットもできる
sns.lmplot("total_bill", "tip", tips, fit_reg = False)

# %%
# 離散的な値でもlmplot()は使える

# %%
# チップの割合を計算する
tips["tip_pect"] = 100 * (tips['tip'] / tips['total_bill'])
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pect
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3  16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2  13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4  14.680765

# %%
# sizeは離散
sns.lmplot("size", "tip_pect", tips)

# %%
# 左右幅を広げる
sns.lmplot("size", "tip_pect", tips, x_jitter = 0.2)

# %%
# 特定の推定量を描画することも出来る
sns.lmplot("size", "tip_pect", tips, x_estimator = np.mean)

# %%
# hueが便利、傾向という意味
sns.lmplot("size", "tip_pect", tips, hue = "sex", markers = ["x", "o"])

# %%
sns.lmplot("size", "tip_pect", tips, hue = "day")

# %% [markdown]
# LOESSの説明
# [http://en.wikipedia.org/wiki/Local_regression](http://en.wikipedia.org/wiki/Local_regression)

# %%
sns.lmplot("total_bill", "tip_pect", tips, lowess=True, line_kws={"color": 'black'});

# %%
# lmplot()は実は、もっと低レベルな関数regplotを使っている
sns.regplot("total_bill", "tip_pect", tips)

# %%
# 描画エリアを分割することもできる
fig, (axis1, axis2) = plt.subplots(1, 2, sharey = True)

sns.regplot("total_bill", "tip_pect", tips, ax = axis1)
sns.violinplot(y = "tip_pect", x = 'size', data = tips.sort_values('size'), ax = axis2)
